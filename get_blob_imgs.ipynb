# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
features = np.load("features.npy", allow_pickle = True)
labels = np.load("labels.npy", allow_pickle = True)

# %%
plt.hist2d(features[labels == 1,0], features[labels == 1,1], bins = (120,120), range = [[0, 2.5],[0, 2.5]])[-1]
# plt.hist2d(features[labels == 0,0], features[labels == 0,1], bins = (100,100), range = [[0, 2.5],[0, 2.5]])[-1]

# %%
plt.scatter(features[labels == 0, 0], features[labels == 0, 1], s = 0.0001)
plt.scatter(features[labels == 1, 0], features[labels == 1, 1], s = 0.0001)
